# %%
# !pip install jitcdde
# Out:
# Collecting jitcdde
#   Using cached jitcdde-1.8.1.tar.gz (164 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: jitcxde_common>1.3 in /Users/shayan/anaconda3/envs/my_adc/lib/python3.9/site-packages (from jitcdde) (1.5.4)
# Requirement already satisfied: symengine>=0.3.1.dev0 in /Users/shayan/anaconda3/envs/my_adc/lib/python3.9/site-packages (from jitcdde) (0.11.0)
# Requirement already satisfied: numpy in /Users/shayan/anaconda3/envs/my_adc/lib/python3.9/site-packages (from jitcdde) (1.26.4)
# Collecting chspy>=1.1 (from jitcdde)
#   Using cached CHSPy-1.2.2.tar.gz (18 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: jinja2 in /Users/shayan/anaconda3/envs/my_adc/lib/python3.9/site-packages (from jitcxde_common>1.3->jitcdde) (3.1.3)
# Requirement already satisfied: setuptools in /Users/shayan/anaconda3/envs/my_adc/lib/python3.9/site-packages (from jitcxde_common>1.3->jitcdde) (69.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/shayan/anaconda3/envs/my_adc/lib/python3.9/site-packages (from jinja2->jitcxde_common>1.3->jitcdde) (2.1.5)
# Building wheels for collected packages: jitcdde, chspy
#   Building wheel for jitcdde (setup.py) ... done
#   Created wheel for jitcdde: filename=jitcdde-1.8.1-py3-none-any.whl size=55003 sha256=dfc47d6e24ca9092002e4da9fd66b784eb7a39b726b35e59649133bd912d3d55
#   Stored in directory: /Users/shayan/Library/Caches/pip/wheels/00/89/2e/de80c769c740b30ddf9e5aa935d293088f6c4876a9ace68e53
#   Building wheel for chspy (setup.py) ... done
#   Created wheel for chspy: filename=CHSPy-1.2.2-py3-none-any.whl size=11999 sha256=4009e6378d20e707236ac0afd90ad5c31282813fa90d306029ab1f9a6e9bf39e
#   Stored in directory: /Users/shayan/Library/Caches/pip/wheels/56/db/67/134465284235bc9e1e6e434bc992e635cf38aa2bf16ce34233
# Successfully built jitcdde chspy
# Installing collected packages: chspy, jitcdde
# Successfully installed chspy-1.2.2 jitcdde-1.8.1

# %%
# !clang --version
# Out:
# Apple clang version 14.0.0 (clang-1400.0.29.202)
# Target: arm64-apple-darwin22.2.0
# Thread model: posix
# InstalledDir: /Library/Developer/CommandLineTools/usr/bin

# %%
from jitcdde import jitcdde, y, t
from numpy import pi, arange, random, max
from symengine import sin

n = 100
ω = 1
c = 42
q = 0.05
A = random.choice( [1,0], size=(n,n), p=[q,1-q] )
τ = random.uniform( pi/5, 2*pi, size=(n,n) )

def kuramotos():
	for i in range(n):
		yield ω + c/(n-1)*sum(
					sin(y(j,t-τ[i,j])-y(i))
					for j in range(n)
					if A[j,i]
				)

I = jitcdde(kuramotos,n=n,verbose=False,delays=τ.flatten())
I.set_integration_parameters(rtol=0,atol=1e-5)

I.constant_past( random.uniform(0,2*pi,n), time=0.0 )
I.integrate_blindly( max(τ) , 0.1 )

for time in I.t + arange(0,400,0.2):
	print(*I.integrate(time) % (2*pi))
# Out:
# clang: error: the clang compiler does not support '-march=native'
# ---------------------------------------------------------------------------
# DistutilsExecError                        Traceback (most recent call last)
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/setuptools/_distutils/unixccompiler.py:185, in UnixCCompiler._compile(self, obj, src, ext, cc_args, extra_postargs, pp_opts)
#     184 try:
# --> 185     self.spawn(compiler_so + cc_args + [src, '-o', obj] + extra_postargs)
#     186 except DistutilsExecError as msg:
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/setuptools/_distutils/ccompiler.py:1041, in CCompiler.spawn(self, cmd, **kwargs)
#    1040 def spawn(self, cmd, **kwargs):
# -> 1041     spawn(cmd, dry_run=self.dry_run, **kwargs)
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/setuptools/_distutils/spawn.py:70, in spawn(cmd, search_path, verbose, dry_run, env)
#      69     cmd = cmd[0]
# ---> 70 raise DistutilsExecError(
#      71     "command {!r} failed with exit code {}".format(cmd, exitcode)
#      72 )
#
# DistutilsExecError: command '/usr/bin/clang' failed with exit code 1
#
# During handling of the above exception, another exception occurred:
#
# CompileError                              Traceback (most recent call last)
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/setuptools/_distutils/core.py:201, in run_commands(dist)
#     200 try:
# --> 201     dist.run_commands()
#     202 except KeyboardInterrupt:
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/setuptools/_distutils/dist.py:969, in Distribution.run_commands(self)
#     968 for cmd in self.commands:
# --> 969     self.run_command(cmd)
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/setuptools/dist.py:963, in Distribution.run_command(self, command)
#     960 # Postpone defaults until all explicit configuration is considered
#     961 # (setup() args, config files, command line and plugins)
# --> 963 super().run_command(command)
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/setuptools/_distutils/dist.py:988, in Distribution.run_command(self, command)
#     987 cmd_obj.ensure_finalized()
# --> 988 cmd_obj.run()
#     989 self.have_run[command] = 1
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/setuptools/command/build_ext.py:89, in build_ext.run(self)
#      88 old_inplace, self.inplace = self.inplace, 0
# ---> 89 _build_ext.run(self)
#      90 self.inplace = old_inplace
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/setuptools/_distutils/command/build_ext.py:345, in build_ext.run(self)
#     344 # Now actually compile and link everything.
# --> 345 self.build_extensions()
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/jitcxde_common/_jitcxde.py:304, in jitcxde._compile_and_load.<locals>.build_ext_with_compiler_detection.build_extensions(self)
#     302 	extension.extra_compile_args = determine_compile_args(is_msvc)
# --> 304 build_ext.build_extensions(self)
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/setuptools/_distutils/command/build_ext.py:467, in build_ext.build_extensions(self)
#     466 else:
# --> 467     self._build_extensions_serial()
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/setuptools/_distutils/command/build_ext.py:493, in build_ext._build_extensions_serial(self)
#     492 with self._filter_build_errors(ext):
# --> 493     self.build_extension(ext)
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/setuptools/command/build_ext.py:250, in build_ext.build_extension(self, ext)
#     249     self.compiler = self.shlib_compiler
# --> 250 _build_ext.build_extension(self, ext)
#     251 if ext._needs_stub:
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/setuptools/_distutils/command/build_ext.py:548, in build_ext.build_extension(self, ext)
#     546     macros.append((undef,))
# --> 548 objects = self.compiler.compile(
#     549     sources,
#     550     output_dir=self.build_temp,
#     551     macros=macros,
#     552     include_dirs=ext.include_dirs,
#     553     debug=self.debug,
#     554     extra_postargs=extra_args,
#     555     depends=ext.depends,
#     556 )
#     558 # XXX outdated variable, kept here in case third-part code
#     559 # needs it.
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/setuptools/_distutils/ccompiler.py:600, in CCompiler.compile(self, sources, output_dir, macros, include_dirs, debug, extra_preargs, extra_postargs, depends)
#     599         continue
# --> 600     self._compile(obj, src, ext, cc_args, extra_postargs, pp_opts)
#     602 # Return *all* object filenames, not just the ones we just built.
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/setuptools/_distutils/unixccompiler.py:187, in UnixCCompiler._compile(self, obj, src, ext, cc_args, extra_postargs, pp_opts)
#     186 except DistutilsExecError as msg:
# --> 187     raise CompileError(msg)
#
# CompileError: command '/usr/bin/clang' failed with exit code 1
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[1], line 24
#      23 I.constant_past( random.uniform(0,2*pi,n), time=0.0 )
# ---> 24 I.integrate_blindly( max(τ) , 0.1 )
#      26 for time in I.t + arange(0,400,0.2):
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/jitcdde/_jitcdde.py:889, in jitcdde.integrate_blindly(self, target_time, step)
#     888 self.initial_discontinuities_handled = True
# --> 889 dt,number,_ = self._prepare_blind_int(target_time, step)
#     891 if number == 0:
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/jitcdde/_jitcdde.py:847, in jitcdde._prepare_blind_int(self, target_time, step)
#     846 def _prepare_blind_int(self, target_time, step):
# --> 847 	self._initiate()
#     849 	step = step or self.max_step
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/jitcdde/_jitcdde.py:546, in jitcdde._initiate(self)
#     545 if self.compile_attempt is None:
# --> 546 	self._attempt_compilation()
#     548 if self.DDE is None:
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/jitcxde_common/_jitcxde.py:242, in jitcxde._attempt_compilation(self, reset)
#     241 try:
# --> 242 	self.compile_C()
#     243 except Exception:
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/jitcdde/_jitcdde.py:542, in jitcdde.compile_C(self, simplify, do_cse, chunk_size, extra_compile_args, extra_link_args, verbose, modulename, omp)
#     529 self._render_template(
#     530 		n = self.n,
#     531 		number_of_helpers = helper_i,
#    (...)
#     539 		callbacks = [(fun.name,n_args) for fun,_,n_args in self.callback_functions],
#     540 	)
# --> 542 self._compile_and_load(verbose,extra_compile_args,extra_link_args,omp)
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/jitcxde_common/_jitcxde.py:306, in jitcxde._compile_and_load(self, verbose, extra_compile_args, extra_link_args, omp)
#     304 		build_ext.build_extensions(self)
# --> 306 setup(
#     307 		name = self._modulename,
#     308 		ext_modules = [extension],
#     309 		script_args = script_args,
#     310 		verbose = verbose,
#     311 		cmdclass = {'build_ext':build_ext_with_compiler_detection}
#     312 	)
#     314 self.jitced = find_and_load_module(self._modulename,self._tmpfile())
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/setuptools/__init__.py:103, in setup(**attrs)
#     102 _install_setup_requires(attrs)
# --> 103 return distutils.core.setup(**attrs)
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/setuptools/_distutils/core.py:185, in setup(**attrs)
#     184 if ok:
# --> 185     return run_commands(dist)
#     187 return dist
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/setuptools/_distutils/core.py:215, in run_commands(dist)
#     214     else:
# --> 215         raise SystemExit("error: " + str(msg))
#     217 return dist
#
# SystemExit: error: command '/usr/bin/clang' failed with exit code 1
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/IPython/core/interactiveshell.py:2121, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2118 if exception_only:
#    2119     stb = ['An exception has occurred, use %tb to see '
#    2120            'the full traceback.\n']
# -> 2121     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    2122                                                      value))
#    2123 else:
#    2125     def contains_exceptiongroup(val):
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/IPython/core/ultratb.py:710, in ListTB.get_exception_only(self, etype, value)
#     702 def get_exception_only(self, etype, value):
#     703     """Only print the exception type and message, without a traceback.
#     704
#     705     Parameters
#    (...)
#     708     value : exception value
#     709     """
# --> 710     return ListTB.structured_traceback(self, etype, value)
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/IPython/core/ultratb.py:568, in ListTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     565     chained_exc_ids.add(id(exception[1]))
#     566     chained_exceptions_tb_offset = 0
#     567     out_list = (
# --> 568         self.structured_traceback(
#     569             etype,
#     570             evalue,
#     571             (etb, chained_exc_ids),  # type: ignore
#     572             chained_exceptions_tb_offset,
#     573             context,
#     574         )
#     575         + chained_exception_message
#     576         + out_list)
#     578 return out_list
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/IPython/core/ultratb.py:1435, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1433 else:
#    1434     self.tb = etb
# -> 1435 return FormattedTB.structured_traceback(
#    1436     self, etype, evalue, etb, tb_offset, number_of_lines_of_context
#    1437 )
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/IPython/core/ultratb.py:1326, in FormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1323 mode = self.mode
#    1324 if mode in self.verbose_modes:
#    1325     # Verbose modes need a full traceback
# -> 1326     return VerboseTB.structured_traceback(
#    1327         self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1328     )
#    1329 elif mode == 'Minimal':
#    1330     return ListTB.get_exception_only(self, etype, value)
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/IPython/core/ultratb.py:1173, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1164 def structured_traceback(
#    1165     self,
#    1166     etype: type,
#    (...)
#    1170     number_of_lines_of_context: int = 5,
#    1171 ):
#    1172     """Return a nice text document describing the traceback."""
# -> 1173     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1174                                                            tb_offset)
#    1176     colors = self.Colors  # just a shorthand + quicker name lookup
#    1177     colorsnormal = colors.Normal  # used a lot
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/IPython/core/ultratb.py:1063, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1060 assert isinstance(tb_offset, int)
#    1061 head = self.prepare_header(str(etype), self.long_header)
#    1062 records = (
# -> 1063     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#    1064 )
#    1066 frames = []
#    1067 skipped = 0
#
# File ~/anaconda3/envs/my_adc/lib/python3.9/site-packages/IPython/core/ultratb.py:1131, in VerboseTB.get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1129 while cf is not None:
#    1130     try:
# -> 1131         mod = inspect.getmodule(cf.tb_frame)
#    1132         if mod is not None:
#    1133             mod_name = mod.__name__
#
# AttributeError: 'tuple' object has no attribute 'tb_frame'
